# %% [markdown]
# # NFL Competition
#
# # Feature Engineering e Modelo de Machine Learning
#
# - Version: 1.0: usando padrao do fork: https://www.kaggle.com/bestpredict/location-eda-8eb410
#         *    Resultado: 0.012744
#         *    LB: 0.01363
#
# - Version: 2.0: adicionado Feature Selection com LOFO Importance
#         *    Resultado: 0.012780
#         *    LB: 0.01365
#
# - Version: 3.0: adicionado novas features (apenas feature fxx + old_data + YardLine_std)
#         *    Resultado: 0.012614
#         *    LB: 0.01361
#
# - Version: 4.0: adicionado novas features (turf)
#         *    Resultado: 0.012624
#         *    LB: 0.01361
#
# - Version: 5.0: adicionado novas features (game_time)
#         *    Resultado: 0.012635
#         *    LB: 0.01362
#
# - Version: 6.0: adicionado novas features (feat1, feat2, feat3, feat4) e removido (Turf + game_time)
#         *    Resultado: 0.012536
#         *    LB: Não é permitido
#
# - Version: 7.0: alteração do modelo de bagging
#         *    Resultado: 0.012474
#         *    LB: 0.01362
#
# - Version: 8.0: adicionado novas features (accY, est_prev_yards)
#         *    Resultado: 0.012616
#         *    LB: 0.01362
#
# - Version: 9.0: adicionado novas features (norm_quat,mod_quat,norm_X,norm_Y,norm_A,norm_S)
#
#         *    Resultado: 0.012604
#         *    LB: 0.01361
#
# - Version: 12.0: realizando stacking dos modelos NN e RF
#
#         *    Resultado: 0.012616
#         *    LB: 0.01361
#
# - Version: 13.0: inclusao de otimização no modelo de NN
#
#         *    Resultado: 0.012587
#         *    LB: 0.01361
#
# - Version: 14.0: usando todos os dados do dataset para treino
#
#         *    Resultado: 0.009x
#         *    LB: 0.01379
#
# - Version: 15.0: adicionando novas features (seconds_need_to_first_down, seconds_need_to_YardsLine, DefendersInTheBox_vs_Distance) e alguns ajustes no modelo
#
#         *    Resultado:
#         *    LB:
#
# - Version: 16.0: removido as linhas com menor quantidade de frequencia de Yards (<=50)
#
#         *    Resultado:
#         *    LB:

# %% [markdown]
# ## 1. Importa os pacotes e o dataset de treino

# %%
# Importar os principais pacotes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
import re
import codecs
import time
import datetime
import gc

# Evitar que aparece os warnings
import warnings
warnings.filterwarnings("ignore")

# Seta algumas opções no Jupyter para exibição dos datasets
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# Variavel para controlar o treinamento no Kaggle
TRAIN_OFFLINE = True

# %%
# Importa os pacotes de algoritmos
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# Importa os pacotes de algoritmos de redes neurais (Keras)
from keras.losses import binary_crossentropy, categorical_crossentropy
from keras.utils import to_categorical
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.layers import Activation
from keras.models import Sequential, Model
from keras.callbacks import Callback,EarlyStopping,ModelCheckpoint
import keras.backend as K
from keras.optimizers import Adam, Nadam, RMSprop
from keras import optimizers

# Importa pacotes do sklearn
from sklearn import preprocessing
import sklearn.metrics as mtr
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.preprocessing import scale, MinMaxScaler, StandardScaler
from sklearn import model_selection
# Out:
# Using TensorFlow backend.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
if TRAIN_OFFLINE:
    train  = pd.read_csv('../data/train.csv', dtype={'WindSpeed': 'object'})
else:
    train  = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %% [markdown]
# ## 2. Feature Engineering

# %%
def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1
    
def get_time(x):
    x = x.split(":")
    return int(x[0])*60 + int(x[1])

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"    
    
def uid_aggregation(comb, main_columns, uids, aggregations):
    X = pd.DataFrame()
    for main_column in main_columns:  
        for col in uids:
            for agg_type in aggregations:
                new_col_name = col+'_'+main_column+'_'+agg_type
                temp_df = comb[[col, main_column]]
                temp_df = temp_df.groupby([col])[main_column].agg([agg_type]).reset_index().rename(
                                                        columns={agg_type: new_col_name})

                temp_df.index = list(temp_df[col])
                temp_df = temp_df[new_col_name].to_dict()   

                X[new_col_name] = comb[col].map(temp_df)
                del temp_df
                gc.collect()
    return X

def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])

def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60

# %%
def create_features_01(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2
        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def velocity(x2, x1, sec) :
        return (x2 - x1) / sec
    
    def diff_x(b, c, theta) :
        if 90.0 < theta < 270.0 :
            return np.sqrt(((b ** 2) + (c ** 2)) - 2 * b * c * np.cos(theta))
        else :
            return 0
        
    def diff_y(b, c, theta) :
        if theta <= 90.0 and theta >= 270.0 :
            return - np.sqrt(((b ** 2) + (c ** 2)) - 2 * b * c * np.cos(theta))
        else :
            return 0
        
    def stop_period(speed, acc) :
        return speed / acc   

    def new_roll_velocity(x1, y1, x2, y2) :  
        x_diff = np.sqrt((x1 - x2) ** 2)
        y_diff = np.sqrt((y1 - y2) ** 2)
        return np.sqrt(x_diff + y_diff) 
    
    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]
        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')
        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X','Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]
        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense

    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA','RusherX', 'RusherY','v_horizontal', 'v_vertical']
        
        return rusher
    
    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append('GameWeather_dense')

        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                                             'YardLine','Quarter','Down','Distance','DefendersInTheBox',
                                                                             'NflId','NflIdRusher','PossessionTeam','HomeTeamAbbr','Turf',
                                                                             'VisitorTeamAbbr','PlayDirection','GameClock','Season','Team',
                                                                             'FieldPosition']].drop_duplicates()

        return static_features

    def combine_features(relative_to_back, defense, rushing, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df

    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, def_feats, rush_feats, static_feats, deploy=deploy)
    
    return basetable

# %%
def create_features_02(t_):
    
    t_['fe1'] = pd.Series(np.sqrt(np.absolute(np.square(t_.X.values) - np.square(t_.Y.values))))
    t_['fe5'] = np.square(t_['S'].values) + 2 * t_['A'].values * t_['Dis'].values  # N
    t_['fe7'] = np.arccos(np.clip(t_['X'].values / t_['Y'].values, -1, 1))  # N
    t_['fe8'] = t_['S'].values / np.clip(t_['fe1'].values, 0.6, None)
    radian_angle = (90 - t_['Dir']) * np.pi / 180.0
    t_['fe10'] = np.abs(t_['S'] * np.cos(radian_angle))
    t_['fe11'] = np.abs(t_['S'] * np.sin(radian_angle))

    t_['IsRusher'] = (t_['NflId'] == t_['NflIdRusher'])
    temp = t_[t_["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    t_ = t_.merge(temp, on = "PlayId")
    t_["IsRusherTeam"] = t_["Team"] == t_["RusherTeam"]    

    t_["is_left"]            = t_["PlayDirection"] == "left"
    t_["old_data"]    = t_["Season"] == 2017
    t_['YardLine_std'] = 100 - t_['YardLine']
    
    t_['Orientation_rad'] = np.mod(t_.Orientation, 360) * np.pi/180.0
    t_.loc[t_.Season >= 2018, 'Orientation_rad'] = np.mod(t_.loc[t_.Season >= 2018, 'Orientation'] - 90, 360) * np.pi/180.0
    t_['Orientation_std'] = t_.Orientation_rad
    t_.loc[t_.is_left, 'Orientation_std'] = np.mod(np.pi + t_.loc[t_.is_left, 'Orientation_rad'], 2*np.pi)
    
    t_['norm_quat'] = (t_['X']**2 + t_['Y']**2 + t_['A']**2 + t_['S']**2)
    t_['mod_quat'] = (t_['norm_quat'])**0.5
    t_['norm_X'] = t_['X'] / t_['mod_quat']
    t_['norm_Y'] = t_['Y'] / t_['mod_quat']
    t_['norm_A'] = t_['A'] / t_['mod_quat']
    t_['norm_S'] = t_['S'] / t_['mod_quat']    

    t_['seconds_need_to_first_down'] = (t_['Distance']*0.9144)/t_['Dis']
    t_['seconds_need_to_YardsLine'] = (t_['YardLine']*0.9144)/t_['Dis']    
    t_['DefendersInTheBox_vs_Distance'] = t_['DefendersInTheBox'] / t_['Distance']    

    t_['time_quarter'] = t_.GameClock.map(lambda x:transform_time_quarter(x))
    t_['time_end'] = t_.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)
    
    t_ = t_.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)

    return t_

# %%
# %time train_basetable = create_features_01(train, False)
# Out:
# CPU times: user 3min 7s, sys: 5.64 s, total: 3min 13s
# Wall time: 3min 1s

# %%
# %time train_basetable = create_features_02(train_basetable)
# Out:
# CPU times: user 2.35 s, sys: 294 ms, total: 2.65 s
# Wall time: 1.63 s

# %%
# Cria uma copia do dataset para backup
X = train_basetable.copy()
X.shape
# Out:
# (23171, 76)

# %%
X['count'] = X.groupby('Yards')['Yards'].transform('count')

# %%
X = X[X['count'] >= 20]
X.shape
# Out:
# (22887, 77)

# %%
import seaborn as sns
from scipy import stats
from scipy.stats import skew, norm

# Analisando a variavel target 'Yards'
sns.set_style("white")
sns.set_color_codes(palette='deep')
f, ax = plt.subplots(figsize=(18, 8))

# Fit a normal distribution
mu, std = norm.fit(train_basetable["Yards"])

# Verificando a distribuicao de frequencia da variavel Yards
sns.distplot(train_basetable["Yards"], color="b", fit = stats.norm)
ax.xaxis.grid(False)
ax.set(ylabel="Frequency")
ax.set(xlabel="Yards")
ax.set(title="Yards distribution: mu = %.2f,  std = %.2f" % (mu, std))
sns.despine(trim=True, left=True)

# Adicionando Skewness e Kurtosis
ax.text(x=1.1, y=1, transform=ax.transAxes, s="Skewness: %f" % train_basetable["Yards"].skew(),\
        fontweight='demibold', fontsize=10, verticalalignment='top', horizontalalignment='right',\
        backgroundcolor='white', color='xkcd:poo brown')
ax.text(x=1.1, y=0.95, transform=ax.transAxes, s="Kurtosis: %f" % train_basetable["Yards"].kurt(),\
        fontweight='demibold', fontsize=10, verticalalignment='top', horizontalalignment='right',\
        backgroundcolor='white', color='xkcd:dried blood')

plt.show()

# %%
import seaborn as sns
from scipy import stats
from scipy.stats import skew, norm

# Analisando a variavel target 'Yards'
sns.set_style("white")
sns.set_color_codes(palette='deep')
f, ax = plt.subplots(figsize=(18, 8))

# Fit a normal distribution
mu, std = norm.fit(X["Yards"])

# Verificando a distribuicao de frequencia da variavel Yards
sns.distplot(X["Yards"], color="b", fit = stats.norm)
ax.xaxis.grid(False)
ax.set(ylabel="Frequency")
ax.set(xlabel="Yards")
ax.set(title="Yards distribution: mu = %.2f,  std = %.2f" % (mu, std))
sns.despine(trim=True, left=True)

# Adicionando Skewness e Kurtosis
ax.text(x=1.1, y=1, transform=ax.transAxes, s="Skewness: %f" % X["Yards"].skew(),\
        fontweight='demibold', fontsize=10, verticalalignment='top', horizontalalignment='right',\
        backgroundcolor='white', color='xkcd:poo brown')
ax.text(x=1.1, y=0.95, transform=ax.transAxes, s="Kurtosis: %f" % X["Yards"].kurt(),\
        fontweight='demibold', fontsize=10, verticalalignment='top', horizontalalignment='right',\
        backgroundcolor='white', color='xkcd:dried blood')

plt.show()

# %%
best_features = ['A','S','back_from_scrimmage','back_oriented_down_field','back_moving_down_field','old_data',
                 'def_mean_dist','def_std_dist','def_min_dist','def_max_dist','min_dist','max_dist','mean_dist',
                 'PlayerAge','PlayerHeight_dense','Dis','DefendersInTheBox',
                 'Distance','Dir','Dir_sin','Dir_cos','YardLine_std','Orientation_std',
                 'WindSpeed_dense','GameWeather_dense',
                 'fe1','fe5','fe8','fe10','fe11',
                 'norm_X','norm_Y','norm_A','norm_S',
                 'RusherDir','RusherS','RusherA','RusherX','RusherY','v_horizontal','v_vertical']

# %%
new_X = X.loc[:,best_features]
new_X.head()
# Out:
#       A     S  back_from_scrimmage  back_oriented_down_field  \
# 0  3.35  3.63                 3.75                         1
# 1  2.41  3.06                 4.07                         0
# 2  2.42  5.77                 3.66                         1
# 3  3.20  4.45                 3.53                         0
# 4  2.53  3.90                 5.01                         0
#
#    back_moving_down_field  old_data  def_mean_dist  def_std_dist  \
# 0                       0      True       9.752491      5.327299
# 1                       0      True      10.297028      5.833217
# 2                       0      True       9.903689      5.073290
# 3                       0      True       6.309354      1.834174
# 4                       0      True      11.056456      5.900009
#
#    def_min_dist  def_max_dist  min_dist   max_dist  mean_dist  PlayerAge  \
# 0      4.593310     22.415872  1.449724  22.415872   8.046559  25.596251
# 1      4.287773     23.025872  0.792023  23.025872   8.614623  25.596252
# 2      4.221670     20.726285  1.646390  20.726285   8.482583  25.596253
# 3      4.528002      9.791231  0.918096   9.791231   5.549379  26.852933
# 4      4.288088     21.214806  0.502892  21.214806   9.168819  22.091819
#
#    PlayerHeight_dense   Dis  DefendersInTheBox  Distance     Dir   Dir_sin  \
# 0                  70  0.38                6.0         2  114.26  0.911690
# 1                  70  0.34                6.0        10   47.80  0.740805
# 2                  70  0.60                7.0        10  138.04  0.668612
# 3                  71  0.46                9.0         2   84.56  0.995496
# 4                  71  0.44                7.0        10  157.92  0.375901
#
#     Dir_cos  YardLine_std  Orientation_std  WindSpeed_dense  \
# 0 -0.410878          55.0         0.314508              8.0
# 1  0.671721          47.0         5.747369              8.0
# 2 -0.743612          25.0         0.683820              8.0
# 3  0.094803          -8.0         6.174626              8.0
# 4 -0.926660          65.0         0.598124              8.0
#
#    GameWeather_dense         fe1      fe5       fe8      fe10      fe11  \
# 0                1.0   27.739531  15.7229  0.130860  3.309436  1.491487
# 1                1.0   40.699869  11.0024  0.075185  2.266862  2.055465
# 2                1.0   68.732841  36.1969  0.083948  3.857889  4.290640
# 3                1.0  101.345209  22.7465  0.043909  4.429957  0.421875
# 4                1.0   12.802566  17.4364  0.304626  1.466013  3.613974
#
#      norm_X    norm_Y    norm_A    norm_S  RusherDir  RusherS  RusherA  \
# 0  0.800098  0.592169  0.064978  0.070409     114.26     3.63     3.35
# 1  0.872224  0.484153  0.042961  0.054547      47.80     3.06     2.41
# 2  0.962497  0.257826  0.032650  0.077847     138.04     5.77     2.42
# 3  0.970517  0.235592  0.029728  0.041340      84.56     4.45     3.20
# 4  0.736852  0.666336  0.062162  0.095823     157.92     3.90     2.53
#
#    RusherX  RusherY  v_horizontal  v_vertical
# 0    41.25    30.53      3.309436    1.491487
# 1    48.93    27.16      2.266862    2.055465
# 2    71.34    19.11      3.857889    4.290640
# 3   104.47    25.36      4.429957    0.421875
# 4    29.99    27.12      1.466013    3.613974

# %% [markdown]
# ## 4. Criar e avaliar alguns algoritmos de Machine Learning

# %% [markdown]
# ### 4.1. Split Treino e Validação

# %%
# Criar um dataset somente com as colunas mais importantes conforme visto anteriormente
#new_X = X.loc[:,best_features]
#new_X.replace(-np.inf,0,inplace=True)
#new_X.replace(np.inf,0,inplace=True)
new_X.fillna(0,inplace=True)

target = X.Yards

y = np.zeros((target.shape[0], 199))
for idx, target in enumerate(list(target)):
    y[idx][99 + target] = 1
    
# Normalizando as variaveis do dataset de treino
scaler = StandardScaler()
new_X = scaler.fit_transform(new_X)
new_X.shape, y.shape
# Out:
# ((22887, 41), (22887, 199))

# %% [markdown]
# ### 4.2. Teste 3 modelos (LightGBM, RF e NN)

# %%
# Calculate CRPS score
def crps_score(y_prediction, y_valid, shape=X.shape[0]):
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_prediction, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * shape)
    crps = np.round(val_s, 6)
    
    return crps

# %%
class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_nn(x_tr,y_tr,x_val,y_val,shape):
    K.clear_session()
    inp = Input(shape = (x_tr.shape[1],))
    
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    
    model.compile(optimizer = optimizers.adam(lr = 0.05, decay = 0.05),
                  loss='categorical_crossentropy', 
                  metrics=[])
     
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=15)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',save_best_only=True, 
                         verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    
    model.fit(x_tr, y_tr,
              callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], 
              epochs=200, 
              #steps_per_epoch = steps,
              batch_size=bsz,
              verbose=1)
    
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    crps = crps_score(y_pred, y_valid, shape=shape)

    return model,crps

# %%
# %%time

loop = 2
fold = 10

oof_nn  = np.zeros([loop, y.shape[0], y.shape[1]])

models_nn = []
crps_csv_nn = []

for k in range(loop):
    kfold = KFold(fold, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(y)):
        print("-----------")
        print(f'Loop {k+1}/{loop}' + f' Fold {k_fold+1}/{fold}')
        print("-----------")
        
        tr_x, tr_y = new_X[tr_inds], y[tr_inds]
        val_x, val_y = new_X[val_inds], y[val_inds]
        
        # Train NN
        nn, crps_nn = get_nn(tr_x, tr_y, val_x, val_y, shape=val_x.shape[0])
        models_nn.append(nn)
        print("the %d fold crps (NN) is %f"%((k_fold+1), crps_nn))
        crps_csv_nn.append(crps_nn)
        
        #Predict OOF
        oof_nn[k, val_inds, :] = nn.predict(val_x)
# Out:
# -----------
# Loop 1/2 Fold 1/10
# -----------
# validation shape 2
# Epoch 1/200
# 20598/20598 [==============================] - 2s 109us/step - loss: 3.5621
#
# Epoch 00001: CRPS_score_val improved from inf to 0.07357, saving model to best_model.h5
# Epoch 2/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.7892
#
# Epoch 00002: CRPS_score_val improved from 0.07357 to 0.01785, saving model to best_model.h5
# Epoch 3/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.7294
#
# Epoch 00003: CRPS_score_val improved from 0.01785 to 0.01293, saving model to best_model.h5
# Epoch 4/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.6923
#
# Epoch 00004: CRPS_score_val improved from 0.01293 to 0.01181, saving model to best_model.h5
# Epoch 5/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6853
#
# Epoch 00005: CRPS_score_val improved from 0.01181 to 0.01152, saving model to best_model.h5
# Epoch 6/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.6773
#
# Epoch 00006: CRPS_score_val improved from 0.01152 to 0.01135, saving model to best_model.h5
# Epoch 7/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.6684
#
# Epoch 00007: CRPS_score_val improved from 0.01135 to 0.01125, saving model to best_model.h5
# Epoch 8/200
# 20598/20598 [==============================] - 2s 84us/step - loss: 2.6602
#
# Epoch 00008: CRPS_score_val improved from 0.01125 to 0.01120, saving model to best_model.h5
# Epoch 9/200
# 20598/20598 [==============================] - 2s 86us/step - loss: 2.6565
#
# Epoch 00009: CRPS_score_val did not improve from 0.01120
# Epoch 10/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.6518
#
# Epoch 00010: CRPS_score_val improved from 0.01120 to 0.01118, saving model to best_model.h5
# Epoch 11/200
# 20598/20598 [==============================] - 2s 85us/step - loss: 2.6480
#
# Epoch 00011: CRPS_score_val improved from 0.01118 to 0.01116, saving model to best_model.h5
# Epoch 12/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.6432
#
# Epoch 00012: CRPS_score_val did not improve from 0.01116
# Epoch 13/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.6431
#
# Epoch 00013: CRPS_score_val improved from 0.01116 to 0.01115, saving model to best_model.h5
# Epoch 14/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.6368
#
# Epoch 00014: CRPS_score_val improved from 0.01115 to 0.01114, saving model to best_model.h5
# Epoch 15/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.6354
#
# Epoch 00015: CRPS_score_val did not improve from 0.01114
# Epoch 16/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.6322
#
# Epoch 00016: CRPS_score_val improved from 0.01114 to 0.01114, saving model to best_model.h5
# Epoch 17/200
# 20598/20598 [==============================] - 2s 77us/step - loss: 2.6315
#
# Epoch 00017: CRPS_score_val improved from 0.01114 to 0.01112, saving model to best_model.h5
# Epoch 18/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.6292
#
# Epoch 00018: CRPS_score_val improved from 0.01112 to 0.01111, saving model to best_model.h5
# Epoch 19/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.6256
#
# Epoch 00019: CRPS_score_val improved from 0.01111 to 0.01111, saving model to best_model.h5
# Epoch 20/200
# 20598/20598 [==============================] - 2s 81us/step - loss: 2.6228
#
# Epoch 00020: CRPS_score_val improved from 0.01111 to 0.01110, saving model to best_model.h5
# Epoch 21/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.6206
#
# Epoch 00021: CRPS_score_val did not improve from 0.01110
# Epoch 22/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.6213
#
# Epoch 00022: CRPS_score_val improved from 0.01110 to 0.01110, saving model to best_model.h5
# Epoch 23/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.6219
#
# Epoch 00023: CRPS_score_val did not improve from 0.01110
# Epoch 24/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.6181
#
# Epoch 00024: CRPS_score_val improved from 0.01110 to 0.01109, saving model to best_model.h5
# Epoch 25/200
# 20598/20598 [==============================] - 1s 73us/step - loss: 2.6169
#
# Epoch 00025: CRPS_score_val improved from 0.01109 to 0.01109, saving model to best_model.h5
# Epoch 26/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.6149
#
# Epoch 00026: CRPS_score_val improved from 0.01109 to 0.01107, saving model to best_model.h5
# Epoch 27/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.6129
#
# Epoch 00027: CRPS_score_val did not improve from 0.01107
# Epoch 28/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6152
#
# Epoch 00028: CRPS_score_val did not improve from 0.01107
# Epoch 29/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6133
#
# Epoch 00029: CRPS_score_val did not improve from 0.01107
# Epoch 30/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.6121
#
# Epoch 00030: CRPS_score_val did not improve from 0.01107
# Epoch 31/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6080
#
# Epoch 00031: CRPS_score_val did not improve from 0.01107
# Epoch 32/200
# 20598/20598 [==============================] - 2s 79us/step - loss: 2.6114
#
# Epoch 00032: CRPS_score_val improved from 0.01107 to 0.01106, saving model to best_model.h5
# Epoch 33/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.6087
#
# Epoch 00033: CRPS_score_val improved from 0.01106 to 0.01106, saving model to best_model.h5
# Epoch 34/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.6047
#
# Epoch 00034: CRPS_score_val improved from 0.01106 to 0.01105, saving model to best_model.h5
# Epoch 35/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.6081
#
# Epoch 00035: CRPS_score_val did not improve from 0.01105
# Epoch 36/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.6075
#
# Epoch 00036: CRPS_score_val improved from 0.01105 to 0.01105, saving model to best_model.h5
# Epoch 37/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.6062
#
# Epoch 00037: CRPS_score_val did not improve from 0.01105
# Epoch 38/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6021
#
# Epoch 00038: CRPS_score_val improved from 0.01105 to 0.01104, saving model to best_model.h5
# Epoch 39/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.6013
#
# Epoch 00039: CRPS_score_val improved from 0.01104 to 0.01103, saving model to best_model.h5
# Epoch 40/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.6031
#
# Epoch 00040: CRPS_score_val did not improve from 0.01103
# Epoch 41/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5961
#
# Epoch 00041: CRPS_score_val did not improve from 0.01103
# Epoch 42/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.6002
#
# Epoch 00042: CRPS_score_val did not improve from 0.01103
# Epoch 43/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.6003
#
# Epoch 00043: CRPS_score_val did not improve from 0.01103
# Epoch 44/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.6007
#
# Epoch 00044: CRPS_score_val improved from 0.01103 to 0.01103, saving model to best_model.h5
# Epoch 45/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.6015
#
# Epoch 00045: CRPS_score_val did not improve from 0.01103
# Epoch 46/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5967
#
# Epoch 00046: CRPS_score_val did not improve from 0.01103
# Epoch 47/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5956
#
# Epoch 00047: CRPS_score_val did not improve from 0.01103
# Epoch 48/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5957
#
# Epoch 00048: CRPS_score_val did not improve from 0.01103
# Epoch 49/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5976
#
# Epoch 00049: CRPS_score_val improved from 0.01103 to 0.01102, saving model to best_model.h5
# Epoch 50/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5931
#
# Epoch 00050: CRPS_score_val improved from 0.01102 to 0.01102, saving model to best_model.h5
# Epoch 51/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5957
#
# Epoch 00051: CRPS_score_val improved from 0.01102 to 0.01101, saving model to best_model.h5
# Epoch 52/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5911
#
# Epoch 00052: CRPS_score_val did not improve from 0.01101
# Epoch 53/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.5920
#
# Epoch 00053: CRPS_score_val did not improve from 0.01101
# Epoch 54/200
# 20598/20598 [==============================] - 2s 95us/step - loss: 2.5911
#
# Epoch 00054: CRPS_score_val did not improve from 0.01101
# Epoch 55/200
# 20598/20598 [==============================] - 2s 85us/step - loss: 2.5948
#
# Epoch 00055: CRPS_score_val did not improve from 0.01101
# Epoch 56/200
# 20598/20598 [==============================] - 2s 92us/step - loss: 2.5913
#
# Epoch 00056: CRPS_score_val improved from 0.01101 to 0.01101, saving model to best_model.h5
# Epoch 57/200
# 20598/20598 [==============================] - 2s 93us/step - loss: 2.5949
#
# Epoch 00057: CRPS_score_val did not improve from 0.01101
# Epoch 58/200
# 20598/20598 [==============================] - 2s 83us/step - loss: 2.5890
#
# Epoch 00058: CRPS_score_val did not improve from 0.01101
# Epoch 59/200
# 20598/20598 [==============================] - 2s 79us/step - loss: 2.5909
#
# Epoch 00059: CRPS_score_val did not improve from 0.01101
# Epoch 60/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5881
#
# Epoch 00060: CRPS_score_val improved from 0.01101 to 0.01101, saving model to best_model.h5
# Epoch 61/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5888
#
# Epoch 00061: CRPS_score_val did not improve from 0.01101
# Epoch 62/200
# 20598/20598 [==============================] - 2s 89us/step - loss: 2.5918
#
# Epoch 00062: CRPS_score_val did not improve from 0.01101
# Epoch 63/200
# 20598/20598 [==============================] - 2s 83us/step - loss: 2.5894
#
# Epoch 00063: CRPS_score_val improved from 0.01101 to 0.01101, saving model to best_model.h5
# Epoch 64/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5886
#
# Epoch 00064: CRPS_score_val improved from 0.01101 to 0.01100, saving model to best_model.h5
# Epoch 65/200
# 20598/20598 [==============================] - 2s 87us/step - loss: 2.5897
#
# Epoch 00065: CRPS_score_val did not improve from 0.01100
# Epoch 66/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5861
#
# Epoch 00066: CRPS_score_val did not improve from 0.01100
# Epoch 67/200
# 20598/20598 [==============================] - 2s 86us/step - loss: 2.5857
#
# Epoch 00067: CRPS_score_val improved from 0.01100 to 0.01100, saving model to best_model.h5
# Epoch 68/200
# 20598/20598 [==============================] - 2s 85us/step - loss: 2.5861
#
# Epoch 00068: CRPS_score_val did not improve from 0.01100
# Epoch 69/200
# 20598/20598 [==============================] - 2s 79us/step - loss: 2.5823
#
# Epoch 00069: CRPS_score_val improved from 0.01100 to 0.01100, saving model to best_model.h5
# Epoch 70/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5817
#
# Epoch 00070: CRPS_score_val improved from 0.01100 to 0.01100, saving model to best_model.h5
# Epoch 71/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5826
#
# Epoch 00071: CRPS_score_val did not improve from 0.01100
# Epoch 72/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5872
#
# Epoch 00072: CRPS_score_val did not improve from 0.01100
# Epoch 73/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5843
#
# Epoch 00073: CRPS_score_val improved from 0.01100 to 0.01100, saving model to best_model.h5
# Epoch 74/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5827
#
# Epoch 00074: CRPS_score_val did not improve from 0.01100
# Epoch 75/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5822
#
# Epoch 00075: CRPS_score_val did not improve from 0.01100
# Epoch 76/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5814
#
# Epoch 00076: CRPS_score_val did not improve from 0.01100
# Epoch 77/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5842
#
# Epoch 00077: CRPS_score_val did not improve from 0.01100
# Epoch 78/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5806
#
# Epoch 00078: CRPS_score_val did not improve from 0.01100
# Epoch 79/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5796
#
# Epoch 00079: CRPS_score_val did not improve from 0.01100
# Epoch 80/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5841
#
# Epoch 00080: CRPS_score_val did not improve from 0.01100
# Epoch 81/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5787
#
# Epoch 00081: CRPS_score_val did not improve from 0.01100
# Epoch 82/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5781
#
# Epoch 00082: CRPS_score_val improved from 0.01100 to 0.01099, saving model to best_model.h5
# Epoch 83/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.5828
#
# Epoch 00083: CRPS_score_val improved from 0.01099 to 0.01099, saving model to best_model.h5
# Epoch 84/200
# 20598/20598 [==============================] - 2s 77us/step - loss: 2.5827
#
# Epoch 00084: CRPS_score_val improved from 0.01099 to 0.01099, saving model to best_model.h5
# Epoch 85/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5772
#
# Epoch 00085: CRPS_score_val improved from 0.01099 to 0.01099, saving model to best_model.h5
# Epoch 86/200
# 20598/20598 [==============================] - 2s 73us/step - loss: 2.5802
#
# Epoch 00086: CRPS_score_val did not improve from 0.01099
# Epoch 87/200
# 20598/20598 [==============================] - 2s 73us/step - loss: 2.5768
#
# Epoch 00087: CRPS_score_val did not improve from 0.01099
# Epoch 88/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5794
#
# Epoch 00088: CRPS_score_val did not improve from 0.01099
# Epoch 89/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5785
#
# Epoch 00089: CRPS_score_val did not improve from 0.01099
# Epoch 90/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5808
#
# Epoch 00090: CRPS_score_val improved from 0.01099 to 0.01099, saving model to best_model.h5
# Epoch 91/200
# 20598/20598 [==============================] - 2s 77us/step - loss: 2.5746
#
# Epoch 00091: CRPS_score_val improved from 0.01099 to 0.01099, saving model to best_model.h5
# Epoch 92/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5754
#
# Epoch 00092: CRPS_score_val did not improve from 0.01099
# Epoch 93/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5770
#
# Epoch 00093: CRPS_score_val did not improve from 0.01099
# Epoch 94/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5731
#
# Epoch 00094: CRPS_score_val improved from 0.01099 to 0.01098, saving model to best_model.h5
# Epoch 95/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5748
#
# Epoch 00095: CRPS_score_val did not improve from 0.01098
# Epoch 96/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5731
#
# Epoch 00096: CRPS_score_val did not improve from 0.01098
# Epoch 97/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5725
#
# Epoch 00097: CRPS_score_val did not improve from 0.01098
# Epoch 98/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5721
#
# Epoch 00098: CRPS_score_val did not improve from 0.01098
# Epoch 99/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5723
#
# Epoch 00099: CRPS_score_val did not improve from 0.01098
# Epoch 100/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5706
#
# Epoch 00100: CRPS_score_val did not improve from 0.01098
# Epoch 101/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5740
#
# Epoch 00101: CRPS_score_val did not improve from 0.01098
# Epoch 102/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5721
#
# Epoch 00102: CRPS_score_val improved from 0.01098 to 0.01098, saving model to best_model.h5
# Epoch 103/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5747
#
# Epoch 00103: CRPS_score_val did not improve from 0.01098
# Epoch 104/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5716
#
# Epoch 00104: CRPS_score_val did not improve from 0.01098
# Epoch 105/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5774
#
# Epoch 00105: CRPS_score_val did not improve from 0.01098
# Epoch 106/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5721
#
# Epoch 00106: CRPS_score_val did not improve from 0.01098
# Epoch 107/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5722
#
# Epoch 00107: CRPS_score_val improved from 0.01098 to 0.01098, saving model to best_model.h5
# Epoch 108/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5694
#
# Epoch 00108: CRPS_score_val did not improve from 0.01098
# Epoch 109/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5710
#
# Epoch 00109: CRPS_score_val did not improve from 0.01098
# Epoch 110/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5737
#
# Epoch 00110: CRPS_score_val did not improve from 0.01098
# Epoch 111/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5730
#
# Epoch 00111: CRPS_score_val did not improve from 0.01098
# Epoch 112/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5684
#
# Epoch 00112: CRPS_score_val did not improve from 0.01098
# Epoch 113/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5739
#
# Epoch 00113: CRPS_score_val did not improve from 0.01098
# Epoch 114/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5689
#
# Epoch 00114: CRPS_score_val did not improve from 0.01098
# Epoch 115/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5666
#
# Epoch 00115: CRPS_score_val did not improve from 0.01098
# Epoch 116/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5716
#
# Epoch 00116: CRPS_score_val did not improve from 0.01098
# Epoch 117/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5718
#
# Epoch 00117: CRPS_score_val improved from 0.01098 to 0.01098, saving model to best_model.h5
# Epoch 118/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5667
#
# Epoch 00118: CRPS_score_val did not improve from 0.01098
# Epoch 119/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5666
#
# Epoch 00119: CRPS_score_val did not improve from 0.01098
# Epoch 120/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5654
#
# Epoch 00120: CRPS_score_val did not improve from 0.01098
# Epoch 121/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5653
#
# Epoch 00121: CRPS_score_val did not improve from 0.01098
# Epoch 122/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5670
#
# Epoch 00122: CRPS_score_val did not improve from 0.01098
# Epoch 123/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5659
#
# Epoch 00123: CRPS_score_val improved from 0.01098 to 0.01097, saving model to best_model.h5
# Epoch 124/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5657
#
# Epoch 00124: CRPS_score_val did not improve from 0.01097
# Epoch 125/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5676
#
# Epoch 00125: CRPS_score_val did not improve from 0.01097
# Epoch 126/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5680
#
# Epoch 00126: CRPS_score_val did not improve from 0.01097
# Epoch 127/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5686
#
# Epoch 00127: CRPS_score_val did not improve from 0.01097
# Epoch 128/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5680
#
# Epoch 00128: CRPS_score_val did not improve from 0.01097
# Epoch 129/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5660
#
# Epoch 00129: CRPS_score_val did not improve from 0.01097
# Epoch 130/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5692
#
# Epoch 00130: CRPS_score_val did not improve from 0.01097
# Epoch 131/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5663
#
# Epoch 00131: CRPS_score_val did not improve from 0.01097
# Epoch 132/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5650
#
# Epoch 00132: CRPS_score_val did not improve from 0.01097
# Epoch 133/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5613
#
# Epoch 00133: CRPS_score_val did not improve from 0.01097
# Epoch 134/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5645
#
# Epoch 00134: CRPS_score_val did not improve from 0.01097
# Epoch 135/200
# 20598/20598 [==============================] - 1s 62us/step - loss: 2.5635
#
# Epoch 00135: CRPS_score_val did not improve from 0.01097
# Epoch 136/200
# 20598/20598 [==============================] - 1s 62us/step - loss: 2.5644
#
# Epoch 00136: CRPS_score_val did not improve from 0.01097
# Epoch 137/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5642
#
# Epoch 00137: CRPS_score_val did not improve from 0.01097
# Epoch 138/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5628
# Restoring model weights from the end of the best epoch
#
# Epoch 00138: CRPS_score_val did not improve from 0.01097
# Epoch 00138: early stopping
# the 1 fold crps (NN) is 0.010972
# -----------
# Loop 1/2 Fold 2/10
# -----------
# validation shape 2
# Epoch 1/200
# 20598/20598 [==============================] - 2s 102us/step - loss: 3.5654
#
# Epoch 00001: CRPS_score_val improved from inf to 0.01659, saving model to best_model.h5
# Epoch 2/200
# 20598/20598 [==============================] - 1s 62us/step - loss: 2.8015
#
# Epoch 00002: CRPS_score_val did not improve from 0.01659
# Epoch 3/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.7238
#
# Epoch 00003: CRPS_score_val improved from 0.01659 to 0.01259, saving model to best_model.h5
# Epoch 4/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.7030
#
# Epoch 00004: CRPS_score_val improved from 0.01259 to 0.01161, saving model to best_model.h5
# Epoch 5/200
# 20598/20598 [==============================] - 1s 73us/step - loss: 2.6873
#
# Epoch 00005: CRPS_score_val improved from 0.01161 to 0.01133, saving model to best_model.h5
# Epoch 6/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.6792
#
# Epoch 00006: CRPS_score_val improved from 0.01133 to 0.01114, saving model to best_model.h5
# Epoch 7/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.6686
#
# Epoch 00007: CRPS_score_val improved from 0.01114 to 0.01107, saving model to best_model.h5
# Epoch 8/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6616
#
# Epoch 00008: CRPS_score_val improved from 0.01107 to 0.01101, saving model to best_model.h5
# Epoch 9/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.6556
#
# Epoch 00009: CRPS_score_val improved from 0.01101 to 0.01098, saving model to best_model.h5
# Epoch 10/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.6464
#
# Epoch 00010: CRPS_score_val improved from 0.01098 to 0.01097, saving model to best_model.h5
# Epoch 11/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.6430
#
# Epoch 00011: CRPS_score_val improved from 0.01097 to 0.01094, saving model to best_model.h5
# Epoch 12/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.6435
#
# Epoch 00012: CRPS_score_val improved from 0.01094 to 0.01092, saving model to best_model.h5
# Epoch 13/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6408
#
# Epoch 00013: CRPS_score_val improved from 0.01092 to 0.01091, saving model to best_model.h5
# Epoch 14/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.6390
#
# Epoch 00014: CRPS_score_val improved from 0.01091 to 0.01089, saving model to best_model.h5
# Epoch 15/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.6358
#
# Epoch 00015: CRPS_score_val improved from 0.01089 to 0.01088, saving model to best_model.h5
# Epoch 16/200
# 20598/20598 [==============================] - 2s 79us/step - loss: 2.6348
#
# Epoch 00016: CRPS_score_val improved from 0.01088 to 0.01087, saving model to best_model.h5
# Epoch 17/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.6336
#
# Epoch 00017: CRPS_score_val improved from 0.01087 to 0.01087, saving model to best_model.h5
# Epoch 18/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.6287
#
# Epoch 00018: CRPS_score_val improved from 0.01087 to 0.01086, saving model to best_model.h5
# Epoch 19/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.6234
#
# Epoch 00019: CRPS_score_val improved from 0.01086 to 0.01084, saving model to best_model.h5
# Epoch 20/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.6244
#
# Epoch 00020: CRPS_score_val improved from 0.01084 to 0.01084, saving model to best_model.h5
# Epoch 21/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.6266
#
# Epoch 00021: CRPS_score_val improved from 0.01084 to 0.01083, saving model to best_model.h5
# Epoch 22/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.6218
#
# Epoch 00022: CRPS_score_val improved from 0.01083 to 0.01082, saving model to best_model.h5
# Epoch 23/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.6213
#
# Epoch 00023: CRPS_score_val did not improve from 0.01082
# Epoch 24/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.6221
#
# Epoch 00024: CRPS_score_val improved from 0.01082 to 0.01081, saving model to best_model.h5
# Epoch 25/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6196
#
# Epoch 00025: CRPS_score_val did not improve from 0.01081
# Epoch 26/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.6191
#
# Epoch 00026: CRPS_score_val improved from 0.01081 to 0.01081, saving model to best_model.h5
# Epoch 27/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.6179
#
# Epoch 00027: CRPS_score_val improved from 0.01081 to 0.01080, saving model to best_model.h5
# Epoch 28/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.6143
#
# Epoch 00028: CRPS_score_val improved from 0.01080 to 0.01079, saving model to best_model.h5
# Epoch 29/200
# 20598/20598 [==============================] - 2s 80us/step - loss: 2.6166
#
# Epoch 00029: CRPS_score_val did not improve from 0.01079
# Epoch 30/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.6140
#
# Epoch 00030: CRPS_score_val improved from 0.01079 to 0.01078, saving model to best_model.h5
# Epoch 31/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.6105
#
# Epoch 00031: CRPS_score_val improved from 0.01078 to 0.01077, saving model to best_model.h5
# Epoch 32/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.6086
#
# Epoch 00032: CRPS_score_val improved from 0.01077 to 0.01077, saving model to best_model.h5
# Epoch 33/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6067
#
# Epoch 00033: CRPS_score_val improved from 0.01077 to 0.01076, saving model to best_model.h5
# Epoch 34/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.6067
#
# Epoch 00034: CRPS_score_val improved from 0.01076 to 0.01076, saving model to best_model.h5
# Epoch 35/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.6073
#
# Epoch 00035: CRPS_score_val did not improve from 0.01076
# Epoch 36/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.6091
#
# Epoch 00036: CRPS_score_val did not improve from 0.01076
# Epoch 37/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.6083
#
# Epoch 00037: CRPS_score_val did not improve from 0.01076
# Epoch 38/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.6075
#
# Epoch 00038: CRPS_score_val improved from 0.01076 to 0.01074, saving model to best_model.h5
# Epoch 39/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.6077
#
# Epoch 00039: CRPS_score_val did not improve from 0.01074
# Epoch 40/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6078: 0s - loss: 2.60
#
# Epoch 00040: CRPS_score_val did not improve from 0.01074
# Epoch 41/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.6028
#
# Epoch 00041: CRPS_score_val did not improve from 0.01074
# Epoch 42/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.6037
#
# Epoch 00042: CRPS_score_val improved from 0.01074 to 0.01074, saving model to best_model.h5
# Epoch 43/200
# 20598/20598 [==============================] - 2s 73us/step - loss: 2.6002
#
# Epoch 00043: CRPS_score_val did not improve from 0.01074
# Epoch 44/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.6027
#
# Epoch 00044: CRPS_score_val improved from 0.01074 to 0.01073, saving model to best_model.h5
# Epoch 45/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5982
#
# Epoch 00045: CRPS_score_val improved from 0.01073 to 0.01073, saving model to best_model.h5
# Epoch 46/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5980
#
# Epoch 00046: CRPS_score_val improved from 0.01073 to 0.01072, saving model to best_model.h5
# Epoch 47/200
# 20598/20598 [==============================] - 2s 73us/step - loss: 2.5980
#
# Epoch 00047: CRPS_score_val did not improve from 0.01072
# Epoch 48/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5980
#
# Epoch 00048: CRPS_score_val improved from 0.01072 to 0.01072, saving model to best_model.h5
# Epoch 49/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.5971
#
# Epoch 00049: CRPS_score_val did not improve from 0.01072
# Epoch 50/200
# 20598/20598 [==============================] - 2s 92us/step - loss: 2.5994
#
# Epoch 00050: CRPS_score_val did not improve from 0.01072
# Epoch 51/200
# 20598/20598 [==============================] - 2s 89us/step - loss: 2.5970
#
# Epoch 00051: CRPS_score_val improved from 0.01072 to 0.01072, saving model to best_model.h5
# Epoch 52/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5970
#
# Epoch 00052: CRPS_score_val did not improve from 0.01072
# Epoch 53/200
# 20598/20598 [==============================] - 2s 81us/step - loss: 2.5969
#
# Epoch 00053: CRPS_score_val improved from 0.01072 to 0.01071, saving model to best_model.h5
# Epoch 54/200
# 20598/20598 [==============================] - 2s 87us/step - loss: 2.5966
#
# Epoch 00054: CRPS_score_val did not improve from 0.01071
# Epoch 55/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5972
#
# Epoch 00055: CRPS_score_val did not improve from 0.01071
# Epoch 56/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5963
#
# Epoch 00056: CRPS_score_val improved from 0.01071 to 0.01071, saving model to best_model.h5
# Epoch 57/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5941
#
# Epoch 00057: CRPS_score_val improved from 0.01071 to 0.01070, saving model to best_model.h5
# Epoch 58/200
# 20598/20598 [==============================] - 2s 103us/step - loss: 2.5918
#
# Epoch 00058: CRPS_score_val did not improve from 0.01070
# Epoch 59/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5907
#
# Epoch 00059: CRPS_score_val improved from 0.01070 to 0.01070, saving model to best_model.h5
# Epoch 60/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5918
#
# Epoch 00060: CRPS_score_val did not improve from 0.01070
# Epoch 61/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5933
#
# Epoch 00061: CRPS_score_val did not improve from 0.01070
# Epoch 62/200
# 20598/20598 [==============================] - 2s 85us/step - loss: 2.5910
#
# Epoch 00062: CRPS_score_val did not improve from 0.01070
# Epoch 63/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5932
#
# Epoch 00063: CRPS_score_val improved from 0.01070 to 0.01070, saving model to best_model.h5
# Epoch 64/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.5939
#
# Epoch 00064: CRPS_score_val did not improve from 0.01070
# Epoch 65/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5895
#
# Epoch 00065: CRPS_score_val improved from 0.01070 to 0.01069, saving model to best_model.h5
# Epoch 66/200
# 20598/20598 [==============================] - 2s 73us/step - loss: 2.5908
#
# Epoch 00066: CRPS_score_val did not improve from 0.01069
# Epoch 67/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5916
#
# Epoch 00067: CRPS_score_val improved from 0.01069 to 0.01069, saving model to best_model.h5
# Epoch 68/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5862
#
# Epoch 00068: CRPS_score_val improved from 0.01069 to 0.01069, saving model to best_model.h5
# Epoch 69/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5878
#
# Epoch 00069: CRPS_score_val did not improve from 0.01069
# Epoch 70/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.5878
#
# Epoch 00070: CRPS_score_val did not improve from 0.01069
# Epoch 71/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5855
#
# Epoch 00071: CRPS_score_val did not improve from 0.01069
# Epoch 72/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5849
#
# Epoch 00072: CRPS_score_val improved from 0.01069 to 0.01069, saving model to best_model.h5
# Epoch 73/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5882
#
# Epoch 00073: CRPS_score_val improved from 0.01069 to 0.01068, saving model to best_model.h5
# Epoch 74/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5859
#
# Epoch 00074: CRPS_score_val improved from 0.01068 to 0.01068, saving model to best_model.h5
# Epoch 75/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5860
#
# Epoch 00075: CRPS_score_val did not improve from 0.01068
# Epoch 76/200
# 20598/20598 [==============================] - 1s 73us/step - loss: 2.5831
#
# Epoch 00076: CRPS_score_val did not improve from 0.01068
# Epoch 77/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5874
#
# Epoch 00077: CRPS_score_val did not improve from 0.01068
# Epoch 78/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5885
#
# Epoch 00078: CRPS_score_val did not improve from 0.01068
# Epoch 79/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5841
#
# Epoch 00079: CRPS_score_val did not improve from 0.01068
# Epoch 80/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5848
#
# Epoch 00080: CRPS_score_val did not improve from 0.01068
# Epoch 81/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5851
#
# Epoch 00081: CRPS_score_val did not improve from 0.01068
# Epoch 82/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5835
#
# Epoch 00082: CRPS_score_val did not improve from 0.01068
# Epoch 83/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5818
#
# Epoch 00083: CRPS_score_val improved from 0.01068 to 0.01068, saving model to best_model.h5
# Epoch 84/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5860
#
# Epoch 00084: CRPS_score_val did not improve from 0.01068
# Epoch 85/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5814
#
# Epoch 00085: CRPS_score_val improved from 0.01068 to 0.01068, saving model to best_model.h5
# Epoch 86/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5801
#
# Epoch 00086: CRPS_score_val did not improve from 0.01068
# Epoch 87/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5807
#
# Epoch 00087: CRPS_score_val did not improve from 0.01068
# Epoch 88/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5827
#
# Epoch 00088: CRPS_score_val did not improve from 0.01068
# Epoch 89/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5819
#
# Epoch 00089: CRPS_score_val did not improve from 0.01068
# Epoch 90/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5792
#
# Epoch 00090: CRPS_score_val did not improve from 0.01068
# Epoch 91/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5802
#
# Epoch 00091: CRPS_score_val did not improve from 0.01068
# Epoch 92/200
# 20598/20598 [==============================] - 2s 84us/step - loss: 2.5798
#
# Epoch 00092: CRPS_score_val did not improve from 0.01068
# Epoch 93/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5808
#
# Epoch 00093: CRPS_score_val did not improve from 0.01068
# Epoch 94/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5778
#
# Epoch 00094: CRPS_score_val did not improve from 0.01068
# Epoch 95/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5795
#
# Epoch 00095: CRPS_score_val did not improve from 0.01068
# Epoch 96/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5821
#
# Epoch 00096: CRPS_score_val did not improve from 0.01068
# Epoch 97/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5797
#
# Epoch 00097: CRPS_score_val improved from 0.01068 to 0.01067, saving model to best_model.h5
# Epoch 98/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5787
#
# Epoch 00098: CRPS_score_val did not improve from 0.01067
# Epoch 99/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5766
#
# Epoch 00099: CRPS_score_val did not improve from 0.01067
# Epoch 100/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5744
#
# Epoch 00100: CRPS_score_val did not improve from 0.01067
# Epoch 101/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5778
#
# Epoch 00101: CRPS_score_val improved from 0.01067 to 0.01067, saving model to best_model.h5
# Epoch 102/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5777
#
# Epoch 00102: CRPS_score_val did not improve from 0.01067
# Epoch 103/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5772
#
# Epoch 00103: CRPS_score_val did not improve from 0.01067
# Epoch 104/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5755
#
# Epoch 00104: CRPS_score_val did not improve from 0.01067
# Epoch 105/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5743
#
# Epoch 00105: CRPS_score_val did not improve from 0.01067
# Epoch 106/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5744
#
# Epoch 00106: CRPS_score_val improved from 0.01067 to 0.01067, saving model to best_model.h5
# Epoch 107/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5738
#
# Epoch 00107: CRPS_score_val did not improve from 0.01067
# Epoch 108/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5755
#
# Epoch 00108: CRPS_score_val improved from 0.01067 to 0.01066, saving model to best_model.h5
# Epoch 109/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5763
#
# Epoch 00109: CRPS_score_val did not improve from 0.01066
# Epoch 110/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5740
#
# Epoch 00110: CRPS_score_val did not improve from 0.01066
# Epoch 111/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5795
#
# Epoch 00111: CRPS_score_val did not improve from 0.01066
# Epoch 112/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5749
#
# Epoch 00112: CRPS_score_val did not improve from 0.01066
# Epoch 113/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5737
#
# Epoch 00113: CRPS_score_val did not improve from 0.01066
# Epoch 114/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5701
#
# Epoch 00114: CRPS_score_val improved from 0.01066 to 0.01066, saving model to best_model.h5
# Epoch 115/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5705
#
# Epoch 00115: CRPS_score_val did not improve from 0.01066
# Epoch 116/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5706
#
# Epoch 00116: CRPS_score_val improved from 0.01066 to 0.01065, saving model to best_model.h5
# Epoch 117/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5695
#
# Epoch 00117: CRPS_score_val did not improve from 0.01065
# Epoch 118/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5751
#
# Epoch 00118: CRPS_score_val did not improve from 0.01065
# Epoch 119/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5717
#
# Epoch 00119: CRPS_score_val did not improve from 0.01065
# Epoch 120/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5734
#
# Epoch 00120: CRPS_score_val did not improve from 0.01065
# Epoch 121/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5729
#
# Epoch 00121: CRPS_score_val did not improve from 0.01065
# Epoch 122/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5701
#
# Epoch 00122: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 123/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5712
#
# Epoch 00123: CRPS_score_val did not improve from 0.01065
# Epoch 124/200
# 20598/20598 [==============================] - 1s 68us/step - loss: 2.5699
#
# Epoch 00124: CRPS_score_val did not improve from 0.01065
# Epoch 125/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5708
#
# Epoch 00125: CRPS_score_val did not improve from 0.01065
# Epoch 126/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5722
#
# Epoch 00126: CRPS_score_val did not improve from 0.01065
# Epoch 127/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5721
#
# Epoch 00127: CRPS_score_val did not improve from 0.01065
# Epoch 128/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5713
#
# Epoch 00128: CRPS_score_val did not improve from 0.01065
# Epoch 129/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5690
#
# Epoch 00129: CRPS_score_val did not improve from 0.01065
# Epoch 130/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5694
#
# Epoch 00130: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 131/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5687
#
# Epoch 00131: CRPS_score_val did not improve from 0.01065
# Epoch 132/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5659
#
# Epoch 00132: CRPS_score_val did not improve from 0.01065
# Epoch 133/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5653
#
# Epoch 00133: CRPS_score_val did not improve from 0.01065
# Epoch 134/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5705
#
# Epoch 00134: CRPS_score_val did not improve from 0.01065
# Epoch 135/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5724
#
# Epoch 00135: CRPS_score_val did not improve from 0.01065
# Epoch 136/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5682
#
# Epoch 00136: CRPS_score_val did not improve from 0.01065
# Epoch 137/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5696
#
# Epoch 00137: CRPS_score_val did not improve from 0.01065
# Epoch 138/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5690
#
# Epoch 00138: CRPS_score_val did not improve from 0.01065
# Epoch 139/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5698
#
# Epoch 00139: CRPS_score_val did not improve from 0.01065
# Epoch 140/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5699
#
# Epoch 00140: CRPS_score_val did not improve from 0.01065
# Epoch 141/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5651
#
# Epoch 00141: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 142/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5656
#
# Epoch 00142: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 143/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5663
#
# Epoch 00143: CRPS_score_val did not improve from 0.01065
# Epoch 144/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5668
#
# Epoch 00144: CRPS_score_val did not improve from 0.01065
# Epoch 145/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5667
#
# Epoch 00145: CRPS_score_val did not improve from 0.01065
# Epoch 146/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5658
#
# Epoch 00146: CRPS_score_val did not improve from 0.01065
# Epoch 147/200
# 20598/20598 [==============================] - 1s 67us/step - loss: 2.5669
#
# Epoch 00147: CRPS_score_val did not improve from 0.01065
# Epoch 148/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5642
#
# Epoch 00148: CRPS_score_val did not improve from 0.01065
# Epoch 149/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5631
#
# Epoch 00149: CRPS_score_val did not improve from 0.01065
# Epoch 150/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5667
#
# Epoch 00150: CRPS_score_val did not improve from 0.01065
# Epoch 151/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5654
#
# Epoch 00151: CRPS_score_val did not improve from 0.01065
# Epoch 152/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5668
#
# Epoch 00152: CRPS_score_val did not improve from 0.01065
# Epoch 153/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5653
#
# Epoch 00153: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 154/200
# 20598/20598 [==============================] - 1s 65us/step - loss: 2.5649
#
# Epoch 00154: CRPS_score_val did not improve from 0.01065
# Epoch 155/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5620
#
# Epoch 00155: CRPS_score_val did not improve from 0.01065
# Epoch 156/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5640
#
# Epoch 00156: CRPS_score_val did not improve from 0.01065
# Epoch 157/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5628
#
# Epoch 00157: CRPS_score_val did not improve from 0.01065
# Epoch 158/200
# 20598/20598 [==============================] - 1s 62us/step - loss: 2.5622
#
# Epoch 00158: CRPS_score_val did not improve from 0.01065
# Epoch 159/200
# 20598/20598 [==============================] - 1s 63us/step - loss: 2.5621
#
# Epoch 00159: CRPS_score_val did not improve from 0.01065
# Epoch 160/200
# 20598/20598 [==============================] - 1s 64us/step - loss: 2.5631
#
# Epoch 00160: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 161/200
# 20598/20598 [==============================] - 1s 66us/step - loss: 2.5609
#
# Epoch 00161: CRPS_score_val improved from 0.01065 to 0.01064, saving model to best_model.h5
# Epoch 162/200
# ...
# Epoch 46/200
# 20598/20598 [==============================] - 2s 77us/step - loss: 2.6002
#
# Epoch 00046: CRPS_score_val improved from 0.01070 to 0.01069, saving model to best_model.h5
# Epoch 47/200
# 20598/20598 [==============================] - 2s 81us/step - loss: 2.6009
#
# Epoch 00047: CRPS_score_val improved from 0.01069 to 0.01069, saving model to best_model.h5
# Epoch 48/200
# 20598/20598 [==============================] - 2s 84us/step - loss: 2.5955
#
# Epoch 00048: CRPS_score_val improved from 0.01069 to 0.01069, saving model to best_model.h5
# Epoch 49/200
# 20598/20598 [==============================] - 2s 80us/step - loss: 2.5971
#
# Epoch 00049: CRPS_score_val did not improve from 0.01069
# Epoch 50/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5976
#
# Epoch 00050: CRPS_score_val did not improve from 0.01069
# Epoch 51/200
# 20598/20598 [==============================] - 2s 91us/step - loss: 2.5966
#
# Epoch 00051: CRPS_score_val improved from 0.01069 to 0.01069, saving model to best_model.h5
# Epoch 52/200
# 20598/20598 [==============================] - 2s 82us/step - loss: 2.5993
#
# Epoch 00052: CRPS_score_val improved from 0.01069 to 0.01068, saving model to best_model.h5
# Epoch 53/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5961
#
# Epoch 00053: CRPS_score_val did not improve from 0.01068
# Epoch 54/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5944
#
# Epoch 00054: CRPS_score_val did not improve from 0.01068
# Epoch 55/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5934
#
# Epoch 00055: CRPS_score_val did not improve from 0.01068
# Epoch 56/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5928
#
# Epoch 00056: CRPS_score_val improved from 0.01068 to 0.01068, saving model to best_model.h5
# Epoch 57/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5893
#
# Epoch 00057: CRPS_score_val improved from 0.01068 to 0.01067, saving model to best_model.h5
# Epoch 58/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5925
#
# Epoch 00058: CRPS_score_val did not improve from 0.01067
# Epoch 59/200
# 20598/20598 [==============================] - 2s 81us/step - loss: 2.5930
#
# Epoch 00059: CRPS_score_val did not improve from 0.01067
# Epoch 60/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5910
#
# Epoch 00060: CRPS_score_val did not improve from 0.01067
# Epoch 61/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5936
#
# Epoch 00061: CRPS_score_val did not improve from 0.01067
# Epoch 62/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5937
#
# Epoch 00062: CRPS_score_val did not improve from 0.01067
# Epoch 63/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5912
#
# Epoch 00063: CRPS_score_val improved from 0.01067 to 0.01067, saving model to best_model.h5
# Epoch 64/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5888
#
# Epoch 00064: CRPS_score_val did not improve from 0.01067
# Epoch 65/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.5917
#
# Epoch 00065: CRPS_score_val improved from 0.01067 to 0.01067, saving model to best_model.h5
# Epoch 66/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5869
#
# Epoch 00066: CRPS_score_val did not improve from 0.01067
# Epoch 67/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5917
#
# Epoch 00067: CRPS_score_val did not improve from 0.01067
# Epoch 68/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5914
#
# Epoch 00068: CRPS_score_val did not improve from 0.01067
# Epoch 69/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5873
#
# Epoch 00069: CRPS_score_val did not improve from 0.01067
# Epoch 70/200
# 20598/20598 [==============================] - 2s 92us/step - loss: 2.5886
#
# Epoch 00070: CRPS_score_val improved from 0.01067 to 0.01066, saving model to best_model.h5
# Epoch 71/200
# 20598/20598 [==============================] - 2s 83us/step - loss: 2.5890
#
# Epoch 00071: CRPS_score_val improved from 0.01066 to 0.01066, saving model to best_model.h5
# Epoch 72/200
# 20598/20598 [==============================] - 2s 77us/step - loss: 2.5860
#
# Epoch 00072: CRPS_score_val did not improve from 0.01066
# Epoch 73/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5886
#
# Epoch 00073: CRPS_score_val did not improve from 0.01066
# Epoch 74/200
# 20598/20598 [==============================] - 2s 81us/step - loss: 2.5868
#
# Epoch 00074: CRPS_score_val did not improve from 0.01066
# Epoch 75/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5861
#
# Epoch 00075: CRPS_score_val did not improve from 0.01066
# Epoch 76/200
# 20598/20598 [==============================] - 2s 84us/step - loss: 2.5857
#
# Epoch 00076: CRPS_score_val improved from 0.01066 to 0.01066, saving model to best_model.h5
# Epoch 77/200
# 20598/20598 [==============================] - 2s 81us/step - loss: 2.5849
#
# Epoch 00077: CRPS_score_val improved from 0.01066 to 0.01066, saving model to best_model.h5
# Epoch 78/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5823
#
# Epoch 00078: CRPS_score_val improved from 0.01066 to 0.01066, saving model to best_model.h5
# Epoch 79/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5846
#
# Epoch 00079: CRPS_score_val improved from 0.01066 to 0.01065, saving model to best_model.h5
# Epoch 80/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5836
#
# Epoch 00080: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 81/200
# 20598/20598 [==============================] - 2s 77us/step - loss: 2.5848
#
# Epoch 00081: CRPS_score_val did not improve from 0.01065
# Epoch 82/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5841
#
# Epoch 00082: CRPS_score_val did not improve from 0.01065
# Epoch 83/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5840
#
# Epoch 00083: CRPS_score_val did not improve from 0.01065
# Epoch 84/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5846
#
# Epoch 00084: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 85/200
# 20598/20598 [==============================] - 2s 77us/step - loss: 2.5838
#
# Epoch 00085: CRPS_score_val did not improve from 0.01065
# Epoch 86/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5809
#
# Epoch 00086: CRPS_score_val improved from 0.01065 to 0.01065, saving model to best_model.h5
# Epoch 87/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5800
#
# Epoch 00087: CRPS_score_val improved from 0.01065 to 0.01064, saving model to best_model.h5
# Epoch 88/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5780
#
# Epoch 00088: CRPS_score_val did not improve from 0.01064
# Epoch 89/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5808
#
# Epoch 00089: CRPS_score_val improved from 0.01064 to 0.01064, saving model to best_model.h5
# Epoch 90/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5792
#
# Epoch 00090: CRPS_score_val improved from 0.01064 to 0.01064, saving model to best_model.h5
# Epoch 91/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5820
#
# Epoch 00091: CRPS_score_val improved from 0.01064 to 0.01064, saving model to best_model.h5
# Epoch 92/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5775
#
# Epoch 00092: CRPS_score_val improved from 0.01064 to 0.01064, saving model to best_model.h5
# Epoch 93/200
# 20598/20598 [==============================] - 2s 77us/step - loss: 2.5758
#
# Epoch 00093: CRPS_score_val did not improve from 0.01064
# Epoch 94/200
# 20598/20598 [==============================] - 2s 80us/step - loss: 2.5814
#
# Epoch 00094: CRPS_score_val did not improve from 0.01064
# Epoch 95/200
# 20598/20598 [==============================] - 2s 78us/step - loss: 2.5803
#
# Epoch 00095: CRPS_score_val did not improve from 0.01064
# Epoch 96/200
# 20598/20598 [==============================] - 2s 84us/step - loss: 2.5766
#
# Epoch 00096: CRPS_score_val did not improve from 0.01064
# Epoch 97/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5789
#
# Epoch 00097: CRPS_score_val improved from 0.01064 to 0.01064, saving model to best_model.h5
# Epoch 98/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5813
#
# Epoch 00098: CRPS_score_val improved from 0.01064 to 0.01063, saving model to best_model.h5
# Epoch 99/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5737
#
# Epoch 00099: CRPS_score_val did not improve from 0.01063
# Epoch 100/200
# 20598/20598 [==============================] - 2s 73us/step - loss: 2.5755
#
# Epoch 00100: CRPS_score_val did not improve from 0.01063
# Epoch 101/200
# 20598/20598 [==============================] - 2s 80us/step - loss: 2.5713
#
# Epoch 00101: CRPS_score_val did not improve from 0.01063
# Epoch 102/200
# 20598/20598 [==============================] - 2s 76us/step - loss: 2.5778
#
# Epoch 00102: CRPS_score_val did not improve from 0.01063
# Epoch 103/200
# 20598/20598 [==============================] - 2s 74us/step - loss: 2.5776
#
# Epoch 00103: CRPS_score_val did not improve from 0.01063
# Epoch 104/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5750
#
# Epoch 00104: CRPS_score_val did not improve from 0.01063
# Epoch 105/200
# 20598/20598 [==============================] - 1s 71us/step - loss: 2.5764
#
# Epoch 00105: CRPS_score_val did not improve from 0.01063
# Epoch 106/200
# 20598/20598 [==============================] - 1s 72us/step - loss: 2.5721
#
# Epoch 00106: CRPS_score_val improved from 0.01063 to 0.01063, saving model to best_model.h5
# Epoch 107/200
# 20598/20598 [==============================] - 1s 69us/step - loss: 2.5738
#
# Epoch 00107: CRPS_score_val did not improve from 0.01063
# Epoch 108/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5751
#
# Epoch 00108: CRPS_score_val improved from 0.01063 to 0.01063, saving model to best_model.h5
# Epoch 109/200
# 20598/20598 [==============================] - 1s 70us/step - loss: 2.5757
#
# Epoch 00109: CRPS_score_val did not improve from 0.01063
# Epoch 110/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5745
#
# Epoch 00110: CRPS_score_val did not improve from 0.01063
# Epoch 111/200
# 20598/20598 [==============================] - 2s 75us/step - loss: 2.5741
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-21-9481a7f3fe0d> in get_nn(x_tr, y_tr, x_val, y_val, shape)
#      39               #steps_per_epoch = steps,
#      40               batch_size=bsz,
# ---> 41               verbose=1)
#      42
#      43     model.load_weights("best_model.h5")
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     214                         epoch_logs['val_' + l] = o
#     215
# --> 216         callbacks.on_epoch_end(epoch, epoch_logs)
#     217         if callbacks.model.stop_training:
#     218             break
#
# ~/anaconda3/lib/python3.7/site-packages/keras/callbacks/callbacks.py in on_epoch_end(self, epoch, logs)
#     150         logs = logs or {}
#     151         for callback in self.callbacks:
# --> 152             callback.on_epoch_end(epoch, logs)
#     153
#     154     def on_train_batch_begin(self, batch, logs=None):
#
# <ipython-input-20-bcc4254fd1e4> in on_epoch_end(self, epoch, logs)
#      25         if (self.validation):
#      26             X_valid, y_valid = self.validation[0], self.validation[1]
# ---> 27             y_pred = self.model.predict(X_valid)
#      28             y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
#      29             y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3738         value = math_ops.cast(value, tensor.dtype)
#    3739       converted_inputs.append(value)
# -> 3740     outputs = self._graph_fn(*converted_inputs)
#    3741
#    3742     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
crps_oof_nn  = []

for k in range(loop):
    crps_oof_nn.append(crps_score(oof_nn[k,...], y))

# %%
print("mean crps (NN) is %f"%np.mean(crps_csv_nn))
print("mean OOF crps (NN) is %f"%np.mean(crps_oof_nn))
# Out:
# mean crps (NN) is 0.010720
# mean OOF crps (NN) is 0.341606

# %% [markdown]
# ## Blending Weight Optimisation

# %%
def predict(x_te, models_nn):
    model_num_nn = len(models_nn)
    for k,m in enumerate(models_nn):
        if k==0:
            y_pred_nn = m.predict(x_te, batch_size=1024)
        else:
            y_pred_nn += m.predict(x_te, batch_size=1024)
            
    y_pred_nn = y_pred_nn / model_num_nn
    
    return y_pred_nn

# %% [markdown]
# ## 5. Realizar a submissão para o Kaggle

# %%
# %%time

if  TRAIN_OFFLINE==False:
    
    from kaggle.competitions import nflrush
    env = nflrush.make_env()
    iter_test = env.iter_test()
    df_prev = pd.DataFrame()
    df_test = pd.DataFrame()

    for (test_df, sample_prediction_df) in tqdm_notebook(iter_test):
        basetable = create_features_01(test_df, deploy=True)
        basetable = create_features_02(basetable)

        # Considerar somente as colunas do Feature Selection
        basetable = basetable.loc[:,best_features]
        basetable.fillna(0,inplace=True)
    
        scaled_basetable = scaler.transform(basetable)

        y_pred = predict(scaled_basetable, models_nn)
        y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]

        preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
        
        df_test = df_test.append(basetable)
        df_prev = df_prev.append(preds_df)
    
        env.predict(preds_df)

    env.write_submission_file()
# Out:
# CPU times: user 3 µs, sys: 2 µs, total: 5 µs
# Wall time: 7.87 µs

# %%
df_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-711c74f5b217> in <module>
# ----> 1 df_test.head()
#
# NameError: name 'df_test' is not defined

# %%
df_prev.head()
